# %%
import sys
import numpy as np
import astropy.io.fits as fits
import matplotlib.pyplot as plt
import copy
sys.path.insert(0, '/home/ryan/projects/CHARM-KASTr/py/')
from extraction import *
from extraction_scripts import *
from standard_reducer import *
from science_reducer import *

# %%
import glob

import astropy.io.fits as fits

biaspath = "/home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/bias/"

flatpath = "/home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/flat/"

BIAS = []

FLAT = []


for filename in glob.glob(biaspath + '*.fits'):
    BIAS.append(fits.open(filename))

for filename in glob.glob(flatpath + '*.fits'):
    FLAT.append(fits.open(filename))

# %%
median_biasframe = cube_median(BIAS)

median_flatframe = cube_median(FLAT)

bias_subtracted_flat = bias_subtract(median_flatframe, median_biasframe)

image_mask = create_mask(bias_subtracted_flat, median_biasframe)

norm_flat = normalize_flat(bias_subtracted_flat, image_mask)

# %%
tpath = '/home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/telluric/r1032.fits'
outpath = '/home/ryan/projects/data_prods/170813/1034/'
objname = 'HD 164595 - Exposure 1'
standard_reducer(tpath, outpath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/telluric/r1032.fits
# Enter Pixel Radius from Peak: 20
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Created the slit trace
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Exported slit trace model to /home/ryan/projects/data_prods/170813/1034/HD 164595 - Exposure 1_slit_trace_model.txt
# Please analyze the spatial profile to select background
# Enter Background Threshold: 0.1
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# Loaded wavelength calibration model
# ...

# %%
tpath = '/home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/telluric/r1033.fits'
outpath = '/home/ryan/projects/data_prods/170813/1034/'
objname = 'HD 164595 - Exposure 2'
standard_reducer(tpath, outpath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/telluric/r1033.fits
# Enter Pixel Radius from Peak: 20
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Created the slit trace
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Exported slit trace model to /home/ryan/projects/data_prods/170813/1034/HD 164595 - Exposure 2_slit_trace_model.txt
# Please analyze the spatial profile to select background
# Enter Background Threshold: 0.1
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# Loaded wavelength calibration model
# ...

# %%
scipath =  '/home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/science/r1034.fits'
outpath = '/home/ryan/projects/data_prods/170813/1034/'
objname = 'J1655+6224 - Exposure 1'
polypath = '/home/ryan/projects/data_prods/170813/1034/slit_trace_model_HD 164595 - Exposure 1.txt'
science_reducer(scipath, outpath, polypath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/science/r1034.fits
# Enter Pixel Radius from Peak: 20
# Loaded slit fit model from /home/ryan/projects/data_prods/170813/1034/slit_trace_model_HD 164595 - Exposure 1.txt
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Generated Centered Image Slices
# Shifted the slit fit
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Please analyze the spatial profile to select background
# Enter Background Threshold: 0.1
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# ...

# %%
scipath =  '/home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/science/r1035.fits'
outpath = '/home/ryan/projects/data_prods/170813/1034/'
objname = 'J1655+6224 - Exposure 2'
polypath = '/home/ryan/projects/data_prods/170813/1034/slit_trace_model_HD 164595 - Exposure 1.txt'
science_reducer(scipath, outpath, polypath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/science/r1035.fits
# Enter Pixel Radius from Peak: 20
# Loaded slit fit model from /home/ryan/projects/data_prods/170813/1034/slit_trace_model_HD 164595 - Exposure 1.txt
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Generated Centered Image Slices
# Shifted the slit fit
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Please analyze the spatial profile to select background
# Enter Background Threshold: 0.1
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# ...

# %%
scipath =  '/home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/science/r1036.fits'
outpath = '/home/ryan/projects/data_prods/170813/1034/'
objname = 'J1655+6224 - Exposure 3'
polypath = '/home/ryan/projects/data_prods/170813/1034/slit_trace_model_HD 164595 - Exposure 1.txt'
science_reducer(scipath, outpath, polypath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2017-08-12-shane-Adam.Burgasser/red/1034/science/r1036.fits
# Enter Pixel Radius from Peak: 20
# Loaded slit fit model from /home/ryan/projects/data_prods/170813/1034/slit_trace_model_HD 164595 - Exposure 1.txt
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Generated Centered Image Slices
# Shifted the slit fit
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Please analyze the spatial profile to select background
# Enter Background Threshold: .1
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# ...
