# %%
import sys
import numpy as np
import astropy.io.fits as fits
import matplotlib.pyplot as plt
import copy
sys.path.insert(0, '/home/ryan/projects/CHARM-KASTr/py/')
from extraction import *
from extraction_scripts import *
from standard_reducer import *
from science_reducer import *

# %%
import glob

import astropy.io.fits as fits

biaspath = "/home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/bias/"

flatpath = "/home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/flat/"

darkpath = "/home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/dark/"

BIAS = []

FLAT = []


for filename in glob.glob(biaspath + '*.fits'):
    BIAS.append(fits.open(filename))

for filename in glob.glob(flatpath + '*.fits'):
    FLAT.append(fits.open(filename))

# %%
median_biasframe = cube_median(BIAS)

median_flatframe = cube_median(FLAT)

bias_subtracted_flat = bias_subtract(median_flatframe, median_biasframe)

image_mask = create_mask(bias_subtracted_flat, median_biasframe)

norm_flat = normalize_flat(bias_subtracted_flat, image_mask)

# %%
tpath = '/home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/telluric/r1085.fits'
outpath = '/home/ryan/projects/data_prods/1084/'
objname = 'HD 79108 - Exposure 1'
standard_reducer(tpath, outpath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/telluric/r1085.fits
# Enter Pixel Radius from Peak: 20
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Created the slit trace
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Exported slit trace model to /home/ryan/projects/data_prods/1084/HD 79108 - Exposure 1_slit_trace_model.txt
# Please analyze the spatial profile to select background
# Enter Background Threshold: 0.1
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# Loaded wavelength calibration model
# ...

# %%
tpath = '/home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/telluric/r1086.fits'
outpath = '/home/ryan/projects/data_prods/1084/'
objname = 'HD 79108 - Exposure 2'
standard_reducer(tpath, outpath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/telluric/r1086.fits
# Enter Pixel Radius from Peak: 20
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Created the slit trace
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Exported slit trace model to /home/ryan/projects/data_prods/1084/HD 79108 - Exposure 2_slit_trace_model.txt
# Please analyze the spatial profile to select background
# Enter Background Threshold: 0.1
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# Loaded wavelength calibration model
# ...

# %%
tpath = '/home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/telluric/r1087.fits'
outpath = '/home/ryan/projects/data_prods/1084/'
objname = 'HD 79108 - Exposure 3'
standard_reducer(tpath, outpath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/telluric/r1087.fits
# Enter Pixel Radius from Peak: 20
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Created the slit trace
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Exported slit trace model to /home/ryan/projects/data_prods/1084/HD 79108 - Exposure 3_slit_trace_model.txt
# Please analyze the spatial profile to select background
# Enter Background Threshold: 0.1
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# Loaded wavelength calibration model
# ...

# %%
scipath =  '/home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/science/r1084.fits'
outpath = '/home/ryan/projects/data_prods/1084/'
objname = 'J0943-0229 - Exposure 1'
polypath = '/home/ryan/projects/data_prods/1084/slit_trace_model_HD 79108 - Exposure 1.txt'
science_reducer(scipath, outpath, polypath, objname, median_biasframe, norm_flat, image_mask)
# Out:
# Loaded image from /home/ryan/projects/KASTr_data/raw/data-2019-03-31-shane-Adam.Burgasser/red/1084/science/r1084.fits
# Enter Pixel Radius from Peak: 20
# Loaded slit fit model from /home/ryan/projects/data_prods/1084/slit_trace_model_HD 79108 - Exposure 1.txt
# Start first stage
# Reduction Ho!
# Loaded image
# Subtracted Bias
# Calculated Variance
# Flat Field Corrected the image
# Flat Field Corrected the variance
# Masked the image
# Masked the variance
# Generated Centered Image Slices
# Shifted the slit fit
# Generated Centered Image Slices
# Generated Centered Variance SLices
# Created spatial profile
# Finish first stage
# Please analyze the spatial profile to select background
# Enter Background Threshold: 0.6
# Begin second stage
# Reduction Continue!
# Subtracted the background from image
# Subtracted the background from variance
# Generated the spectral weighting function
# Extracted the spectrum
# Extracted the variance
# Finish second stage
# ...
