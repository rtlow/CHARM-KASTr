# %%
import astropy.io.fits as fits
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline
fold = '/Volumes/Data/kast/170813/data/'

# %%
hdu = fits.open(fold+'r1053.fits')
data = hdu[0].data
hdu.close()

# %%
plt.imshow(data)
# Out:
# /Users/adam/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/adam/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
xpk = []
impc = []
for i in range(len(data[:,0])):
    slc = data[i,:]
    xpk.append(numpy.argmax(slc))
    if xpk[-1] > 150 and xpk[-1] < 165:
        impc.append(slc[xpk[-1]-10:xpk[-1]+10])
plt.plot(numpy.sum(impc,axis=1))

# %%
numpy.median?
